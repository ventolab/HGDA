# %%
library(reshape2)

# %% [markdown]
# # Load results and explore

# %%
result = read.csv('cellphoneDB/out_Rversion_sPAX8/relevant_interactions.txt', stringsAsFactors = F, sep = '\t')

# %% [markdown]
# ## Medulla

# %%
cell1 = 'Somatic.Sertoli'
cell2 = 'Somatic.late_sPAX8'
combibations = c(paste(cell1, cell2, sep='...'), paste(cell2, cell1, sep='...'))

idx_cl = which(colnames(result) %in%  combibations) 
idx_row = result[combibations[1]] == 1 | result[combibations[2]] == 1

subset(result, idx_row )[, c(2,5:6, idx_cl)]
# Out:
#     interacting_pair                              gene_a gene_b
# 16  LRPAP1_SORT1                                  LRPAP1 SORT1
# 136 FRZB_WNT2B                                    FRZB   WNT2B
# 141 FZD2_LRP5_WNT6                                       WNT6
# 142 FZD2_LRP6_WNT6                                       WNT6
# 143 FZD3_LRP5_WNT6                                       WNT6
# 144 FZD3_LRP6_WNT6                                       WNT6
# 145 FZD4_LRP5_WNT6                                       WNT6
# 146 FZD4_LRP6_WNT6                                       WNT6
# 149 FZD6_LRP5_WNT6                                       WNT6
# 150 FZD6_LRP6_WNT6                                       WNT6
# 158 SFRP1_WNT6                                    SFRP1  WNT6
# 159 FRZB_WNT6                                     FRZB   WNT6
# 161 WIF1_WNT6                                     WIF1   WNT6
# 169 FZD4_LRP5_NDP                                        NDP
# 186 CADM1_CADM1                                   CADM1  CADM1
# 317 FN1_integrin_a3b1_complex                     FN1
# 319 LAMA3_integrin_a3b1_complex                   LAMA3
# 325 FN1_integrin_a8b1_complex                     FN1
# 326 TNC_integrin_a8b1_complex                     TNC
# 327 FN1_integrin_aVb1_complex                     FN1
# 330 FN1_integrin_aVb5_complex                     FN1
# 331 LAMC1_integrin_a6b1_complex                   LAMC1
# 372 BMPR1A_BMPR2_BMP4                                    BMP4
# 381 Androstenedione_byCYP17A1_AR                         AR
# 383 ERBB3_NRG1                                    ERBB3  NRG1
# 389 CD74_APP                                      CD74   APP
# 393 ABCA1_APOA1                                   ABCA1  APOA1
# 394 Cholesterol_byDHCR24_RORA                            RORA
# 406 NRP2_VEGFA                                    NRP2   VEGFA
# 418 NRP2_SEMA3C                                   NRP2   SEMA3C
# 442 MDK_PTPRZ1                                    MDK    PTPRZ1
# 443 PTN_PTPRZ1                                    PTN    PTPRZ1
# 446 PDGFA_PDGFRA                                  PDGFA  PDGFRA
# 460 WNT5A_FRZB                                    WNT5A  FRZB
# 482 MIS_receptor_1_AMH                                   AMH
# 486 AGRN_NCAM1                                    AGRN   NCAM1
# 487 FGFR1_NCAM1                                   FGFR1  NCAM1
# 489 JAG1_NOTCH2                                   JAG1   NOTCH2
# 490 DLK1_NOTCH2                                   DLK1   NOTCH2
# 512 NRG1_ERBB4                                    NRG1   ERBB4
# 520 EPHB6_EFNB1                                   EPHB6  EFNB1
# 524 EPHB1_EFNB1                                   EPHB1  EFNB1
# 538 GPR37_PSAP                                    GPR37  PSAP
# 558 SLIT2_ROBO1                                   SLIT2  ROBO1
# 559 SLIT2_ROBO2                                   SLIT2  ROBO2
# 569 IGFBP3_TMEM219                                IGFBP3 TMEM219
# 574 AR_Testosterone_byHSD17B12                    AR
# 583 AXL_GAS6                                      AXL    GAS6
# 584 TYRO3_GAS6                                    TYRO3  GAS6
# 588 SSTR3_SST                                     SSTR3  SST
# 594 DSC2_DSG2                                     DSC2   DSG2
# 596 NTRK2_NTN4                                    NTRK2  NTN4
# 599 RAreceptor_RARA_atRetinoicAcid_byALDH1A1
# 600 RAreceptor_RARA_RXRA_atRetinoicAcid_byALDH1A1
# 604 RAreceptor_RXRA_atRetinoicAcid_byALDH1A1
# 605 RAreceptor_RXRB_atRetinoicAcid_byALDH1A1
# 606 RAreceptor_RXRG_atRetinoicAcid_byALDH1A1
#     Somatic.Sertoli...Somatic.late_sPAX8 Somatic.late_sPAX8...Somatic.Sertoli
# 16  1                                    1
# 136 1                                    0
# 141 0                                    1
# 142 0                                    1
# 143 0                                    1
# 144 0                                    1
# 145 0                                    1
# 146 0                                    1
# 149 0                                    1
# 150 0                                    1
# 158 0                                    1
# 159 1                                    1
# 161 0                                    1
# 169 1                                    0
# 186 1                                    1
# 317 0                                    1
# 319 1                                    0
# 325 0                                    1
# 326 0                                    1
# 327 0                                    1
# 330 0                                    1
# 331 0                                    1
# 372 1                                    0
# 381 1                                    0
# 383 1                                    0
# 389 0                                    1
# 393 1                                    0
# 394 1                                    0
# 406 0                                    1
# 418 0                                    1
# 442 0                                    1
# 443 0                                    1
# 446 1                                    0
# 460 0                                    1
# 482 0                                    1
# 486 1                                    1
# 487 1                                    1
# 489 0                                    1
# 490 0                                    1
# 512 0                                    1
# 520 1                                    0
# 524 1                                    0
# 538 1                                    0
# 558 0                                    1
# 559 0                                    1
# 569 0                                    1
# 574 0                                    1
# 583 1                                    1
# 584 1                                    1
# 588 1                                    0
# 594 1                                    1
# 596 0                                    1
# 599 0                                    1
# 600 0                                    1
# 604 0                                    1
# 605 0                                    1
# 606 0                                    1

# %%
cell1 = 'Endo.Arterial_EC'
cell2 = 'Somatic.late_sPAX8'
combibations = c(paste(cell1, cell2, sep='...'), paste(cell2, cell1, sep='...'))

idx_cl = which(colnames(result) %in%  combibations) 
idx_row = result[combibations[1]] == 1 | result[combibations[2]] == 1

subset(result, idx_row )[, c(2,5:6, idx_cl)]
# Out:
#     interacting_pair                         gene_a  gene_b
# 11  TNC_integrin_a9b1_complex                TNC
# 16  LRPAP1_SORT1                             LRPAP1  SORT1
# 169 FZD4_LRP5_NDP                                    NDP
# 277 COL9A3_integrin_a1b1_complex             COL9A3
# 290 FN1_integrin_a2b1_complex                FN1
# 308 COL9A3_integrin_a2b1_complex             COL9A3
# 317 FN1_integrin_a3b1_complex                FN1
# 318 THBS1_integrin_a3b1_complex              THBS1
# 321 FN1_integrin_a5b1_complex                FN1
# 324 FBN1_integrin_a5b1_complex               FBN1
# 325 FN1_integrin_a8b1_complex                FN1
# 326 TNC_integrin_a8b1_complex                TNC
# 327 FN1_integrin_aVb1_complex                FN1
# 330 FN1_integrin_aVb5_complex                FN1
# 341 TGFB2_TGFBR3                             TGFB2   TGFBR3
# 381 Androstenedione_byCYP17A1_AR                     AR
# 389 CD74_APP                                 CD74    APP
# 393 ABCA1_APOA1                              ABCA1   APOA1
# 406 NRP2_VEGFA                               NRP2    VEGFA
# 409 NRP2_PGF                                 NRP2    PGF
# 417 NRP2_SEMA3F                              NRP2    SEMA3F
# 420 AGRN_PTPRS                               AGRN    PTPRS
# 486 AGRN_NCAM1                               AGRN    NCAM1
# 487 FGFR1_NCAM1                              FGFR1   NCAM1
# 507 CXCL12_CXCR4                             CXCL12  CXCR4
# 541 TGFB2_TGFbeta_receptor1                  TGFB2
# 544 TGFB2_TGFbeta_receptor2                  TGFB2
# 553 TNFSF12_TNFRSF12A                        TNFSF12 TNFRSF12A
# 558 SLIT2_ROBO1                              SLIT2   ROBO1
# 569 IGFBP3_TMEM219                           IGFBP3  TMEM219
# 574 AR_Testosterone_byHSD17B12               AR
# 581 LGALS3_MERTK                             LGALS3  MERTK
# 584 TYRO3_GAS6                               TYRO3   GAS6
# 585 MERTK_GAS6                               MERTK   GAS6
# 586 SSTR1_SST                                SSTR1   SST
# 606 RAreceptor_RXRG_atRetinoicAcid_byALDH1A1
#     Endo.Arterial_EC...Somatic.late_sPAX8 Somatic.late_sPAX8...Endo.Arterial_EC
# 11  0                                     1
# 16  1                                     0
# 169 1                                     0
# 277 0                                     1
# 290 0                                     1
# 308 0                                     1
# 317 1                                     1
# 318 1                                     0
# 321 0                                     1
# 324 0                                     1
# 325 0                                     1
# 326 0                                     1
# 327 0                                     1
# 330 0                                     1
# 341 0                                     1
# 381 0                                     1
# 389 0                                     1
# 393 1                                     0
# 406 0                                     1
# 409 0                                     1
# 417 0                                     1
# 420 0                                     1
# 486 1                                     0
# 487 1                                     0
# 507 1                                     0
# 541 0                                     1
# 544 0                                     1
# 553 1                                     0
# 558 0                                     1
# 569 0                                     1
# 574 0                                     1
# 581 0                                     1
# 584 1                                     0
# 585 1                                     0
# 586 1                                     0
# 606 0                                     1
