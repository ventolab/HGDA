# %% [markdown]
# # FCA sn analysis for FEMALES - Supporting reanalysis

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import anndata
import os
import sys

def MovePlots(plotpattern, subplotdir):
    os.system('mkdir -p '+str(sc.settings.figdir)+'/'+subplotdir)
    os.system('mv '+str(sc.settings.figdir)+'/*'+plotpattern+'** '+str(sc.settings.figdir)+'/'+subplotdir)

sc.settings.verbosity = 3  # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.settings.figdir = './figures-sn/clustering_males/supporting/'
sc.logging.print_versions()
sc.settings.set_figure_params(dpi=80)  # low dpi (dots per inch) yields small inline figures

sys.executable
# Out:
# WARNING: If you miss a compact list, please try `print_header`!
# -----
# anndata     0.7.5
# scanpy      1.7.0rc1
# sinfo       0.3.1
# -----
# PIL                 8.1.2
# anndata             0.7.5
# anyio               NA
# attr                20.3.0
# babel               2.9.0
# backcall            0.2.0
# brotli              NA
# cairo               1.20.0
# certifi             2020.12.05
# cffi                1.14.5
# chardet             4.0.0
# cloudpickle         1.6.0
# colorama            0.4.4
# cycler              0.10.0
# cython_runtime      NA
# cytoolz             0.11.0
# dask                2021.03.0
# dateutil            2.8.1
# decorator           4.4.2
# get_version         2.1
# google              NA
# h5py                2.10.0
# idna                2.10
# igraph              0.9.1
# ipykernel           5.5.0
# ipython_genutils    0.2.0
# jedi                0.18.0
# jinja2              2.11.3
# joblib              1.0.1
# json5               NA
# jsonschema          3.2.0
# jupyter_server      1.4.1
# jupyterlab_server   2.3.0
# kiwisolver          1.3.1
# legacy_api_wrap     0.0.0
# leidenalg           0.8.3
# llvmlite            0.34.0
# louvain             0.7.0
# markupsafe          1.1.1
# matplotlib          3.3.4
# mpl_toolkits        NA
# natsort             7.1.1
# nbclassic           NA
# nbformat            5.1.2
# numba               0.51.2
# numexpr             2.7.3
# numpy               1.20.1
# packaging           20.9
# pandas              1.1.4
# parso               0.8.1
# pexpect             4.8.0
# pickleshare         0.7.5
# pkg_resources       NA
# prometheus_client   NA
# prompt_toolkit      3.0.16
# psutil              5.8.0
# ptyprocess          0.7.0
# pvectorc            NA
# pygments            2.8.0
# pyparsing           2.4.7
# pyrsistent          NA
# pytoml              NA
# pytz                2021.1
# requests            2.25.1
# ruamel              NA
# scanpy              1.7.0rc1
# scipy               1.6.1
# send2trash          NA
# setuptools_scm      NA
# sinfo               0.3.1
# six                 1.15.0
# sklearn             0.22
# sniffio             1.2.0
# socks               1.7.1
# sphinxcontrib       NA
# storemagic          NA
# tables              3.6.1
# tblib               1.7.0
# texttable           1.6.3
# tlz                 0.11.0
# toolz               0.11.1
# tornado             6.1
# traitlets           5.0.5
# typing_extensions   NA
# urllib3             1.26.3
# wcwidth             0.2.5
# yaml                5.1.2
# zmq                 22.0.3
# -----
# IPython             7.21.0
# jupyter_client      6.1.11
# jupyter_core        4.7.1
# jupyterlab          3.0.9
# notebook            6.2.0
# -----
# Python 3.8.8 | packaged by conda-forge | (default, Feb 20 2021, 16:22:27) [GCC 9.3.0]
# Linux-4.15.0-112-generic-x86_64-with-glibc2.10
# 26 logical CPU cores, x86_64
# -----
# Session information updated at 2021-04-23 14:50
# '/opt/conda/bin/python'

# %% [markdown]
# ## Load data

# %%
adata = sc.read('FCAsn-M3denoised_clusters_male.h5ad')
adata.X.shape
# Out:
# (2822, 29117)

# %% [markdown]
# ## Filter supporting

# %%
sc.pl.dotplot(adata, ['WNT6', 'SOX9', 'AMH',  'LGR5', 'UPK3B', 'NR5A1', 'INSL3', 'PTCH2', 'DCN', 'KRT19', 'PAX8','DAZL', 'EPCAM'], groupby='leiden', standard_scale='var')

# %%
adata = adata[[ i in ['3', '0', '2'] for i in adata.obs['leiden']]]

# %%
print('Total number of cells: {:d}'.format(adata.n_obs))
print('Total number of genes: {:d}'.format(adata.n_vars))
# Out:
# Total number of cells: 1568
# Total number of genes: 29117

# %% [markdown]
# ### Reset an reanalize

# %%
# Save relevant information
ccgs = adata.uns['ccgs']
# Re-set the object to the raw
adata = anndata.AnnData(X=adata.raw.X,var=adata.raw.var,obs=adata.obs)
print('Total number of cells: {:d}'.format(adata.n_obs))
print('Total number of genes: {:d}'.format(adata.n_vars))
# Out:
# Total number of cells: 1568
# Total number of genes: 29383

# %% [markdown]
# ## Preprocess the data again
#
# #### Filter non-expressed genes

# %%
sc.pp.filter_genes(adata, min_cells=5)
adata.raw = adata.copy()
# Out:
# filtered out 6632 genes that are detected in less than 5 cells

# %% [markdown]
# #### CCG, no need to redefine

# %%
# adata.uns['ccgs'] = ccgs
# adata = adata[:,[i not in adata.uns['ccgs'] for i in adata.var_names]]

# %% [markdown]
# #### Normalize per cell

# %%
sc.pp.normalize_per_cell(adata, counts_per_cell_after=1e4)
# Out:
# normalizing by total count per cell
#     finished (0:00:00): normalized adata.X and added    'n_counts', counts per cell before normalization (adata.obs)

# %%
sc.pp.log1p(adata)

# %% [markdown]
# ### Filter HVGs in bdata and do PCA with them

# %%
bdata = adata.copy()
sc.pp.highly_variable_genes(bdata, )
for col in ['highly_variable','means', 'dispersions', 'dispersions_norm']:
    adata.var[col] = bdata.var[col]
bdata = bdata[:, bdata.var['highly_variable']]
print('Total number of cells: {:d}'.format(bdata.n_obs))
print('Total number of genes: {:d}'.format(bdata.n_vars))
# Out:
# extracting highly variable genes
#     finished (0:00:00)
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'means', float vector (adata.var)
#     'dispersions', float vector (adata.var)
#     'dispersions_norm', float vector (adata.var)
# Total number of cells: 1568
# Total number of genes: 4565

# %%
sc.pp.scale(bdata, max_value=10)
sc.tl.pca(bdata, svd_solver='arpack', n_comps=50)
# Out:
# /opt/conda/lib/python3.8/site-packages/scanpy/preprocessing/_simple.py:810: UserWarning: Revieved a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# computing PCA
#     on highly variable genes
#     with n_comps=50
#     finished (0:00:00)

# %% [markdown]
# ## Transfer PCA to the main adata

# %%
#fill NaNs with False so that subsetting to HVGs is possible
adata.var['highly_variable'].fillna(value=False, inplace=True)
adata.obsm['X_pca'] = bdata.obsm['X_pca'].copy()
adata.uns['pca'] = bdata.uns['pca'].copy()
adata.varm['PCs'] = np.zeros(shape=(adata.n_vars, 50))
adata.varm['PCs'][adata.var['highly_variable']] = bdata.varm['PCs']
sc.pl.pca_variance_ratio(adata, log=True, save='.pdf')
# Out:
# WARNING: saving figure to file figures-sn/clustering_males/supporting/pca_variance_ratio.pdf

# %% [markdown]
# #### Scale and regress out cell cycle genes

# %%
# Scale
sc.pp.scale(adata, max_value=10)
# Out:
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption

# %% [markdown]
# ### UMAP

# %%
n_pcs = 10

# %%
# Visualize
sc.pp.neighbors(adata, n_pcs = n_pcs)
sc.tl.umap(adata)
# Out:
# computing neighbors
#     using 'X_pca' with n_pcs = 10
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:13)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:02)

# %% [markdown]
# ## Clustering the graph
# As Seurat and many others, we use the leiden graph-clustering method (community detection based on optimizing modularity). It has been proposed for single-cell data by Levine et al. (2015).

# %%
sc.tl.leiden(adata, resolution=0.3)
# sc.tl.leiden(adata, resolution=0.2)
# Out:
# running Leiden clustering
#     finished: found 5 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:00)

# %%
sc.pl.umap(adata, color=['leiden', 'sample'] )
sc.pl.umap(adata, color=['leiden'],legend_loc='on data',save='_clustering_clusnumbers.pdf' )
# Out:
# WARNING: saving figure to file figures-sn/clustering_males/supporting/umap_clustering_clusnumbers.pdf

# %% [markdown]
# ### Visualize general markers

# %%
sc.pl.umap(adata, color=['MKI67', 'CDK1'], save='-markers_cycling.pdf',color_map='OrRd', use_raw=True)
# Out:
# WARNING: saving figure to file figures-sn/clustering_males/supporting/umap-markers_cycling.pdf

# %%
sc.pl.umap(adata, color=['AMH',  'SOX9', 'LGR5', 'SRY', 'PAX8', 'CYP26B1'], color_map='OrRd', use_raw=False )
sc.pl.umap(adata, color=[ 'UPK3B', 'NR5A1','WNT6', 'WIPF3'], color_map='OrRd', use_raw=False )
sc.pl.umap(adata, color=[ 'INSL3',  'PTCH1',  'PTCH2',  'STAR'], color_map='OrRd', use_raw=False )

# %% [markdown]
# ### Check global trends

# %%
sc.pl.violin(adata, keys= ['n_genes', 'n_counts'], groupby = 'leiden', save='_clusters_statsI.pdf', rotation = 90)
sc.pl.violin(adata, keys= ['percent_mito', 'scrublet_score', 'scrublet_cluster_score'], groupby = 'leiden', save='_clusters_statsII.pdf', rotation = 90)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-c154b1059611> in <module>
# ----> 1 sc.pl.violin(adata, keys= ['n_genes', 'n_counts'], groupby = 'leiden', save='_clusters_statsI.pdf', rotation = 90)
#       2 sc.pl.violin(adata, keys= ['percent_mito', 'scrublet_score', 'scrublet_cluster_score'], groupby = 'leiden', save='_clusters_statsII.pdf', rotation = 90)
#
# /opt/conda/lib/python3.8/site-packages/scanpy/plotting/_anndata.py in violin(adata, keys, groupby, log, use_raw, stripplot, jitter, size, layer, scale, order, multi_panel, xlabel, ylabel, rotation, show, save, ax, **kwds)
#     686     A :class:`~matplotlib.axes.Axes` object if `ax` is `None` else `None`.
#     687     """
# --> 688     import seaborn as sns  # Slow import, only import if called
#     689
#     690     sanitize_anndata(adata)
#
# /opt/conda/lib/python3.8/site-packages/seaborn/__init__.py in <module>
#       6 from .regression import *  # noqa: F401,F403
#       7 from .categorical import *  # noqa: F401,F403
# ----> 8 from .distributions import *  # noqa: F401,F403
#       9 from .matrix import *  # noqa: F401,F403
#      10 from .miscplot import *  # noqa: F401,F403
#
# /opt/conda/lib/python3.8/site-packages/seaborn/distributions.py in <module>
#    1457
#    1458
# -> 1459 histplot.__doc__ = """\
#    1460 Plot univariate or bivariate histograms to show distributions of datasets.
#    1461
#
# /opt/conda/lib/python3.8/site-packages/seaborn/_docstrings.py in __getattr__(self, attr)
#      23         self.entries = entries
#      24
# ---> 25     def __getattr__(self, attr):
#      26         """Provided dot access to entries."""
#      27         if attr in self.entries:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Save adata

# %%
adata.write('FCAsn-M7supporting_male.h5ad')

# %% [markdown]
# # Finding marker genes
#
# Compute a ranking for the highly differential genes in each cluster. Here, we simply rank genes with a t test, which agrees quite well with Seurat.

# %% [markdown]
# ## All vs rest

# %% [markdown]
# ### TF-IDF based

# %%
#Compute Mann-Withney test with scanpy
sc.tl.rank_genes_groups(adata, groupby='leiden', use_raw=False) #, method='logreg'
#Plot TF-IDF values
sc.pl.rank_genes_groups_dotplot(adata, n_genes=20, dendrogram=False, save='_scanpy.pdf', standard_scale = 'var')

# %%
adata_counts = anndata.AnnData(X=adata.raw.X, var=adata.raw.var, obs=adata.obs, asview=False)

# Binarize counts matrix (1 if expressed, 0 otherwise)
import episcanpy as epi
adata_bin = epi.pp.binarize(adata_counts, copy=True)
adata_bin.X.shape
# Compute TF-IDF
from sklearn.feature_extraction.text import TfidfTransformer
transformer = TfidfTransformer()
tfidf = transformer.fit_transform(adata_bin.X.T)
adata_bin.X = tfidf.T
adata_bin.X.shape

#Compute Mann-Withney test with scanpy
sc.tl.rank_genes_groups(adata_bin, groupby='leiden', use_raw=False) #, method='logreg'

#Plot TF-IDF values
sc.pl.rank_genes_groups_dotplot(adata_bin, n_genes=20, dendrogram=False, save='_rawtfidf_scanpy.pdf')

# Plot with gene expression normalized values
sc.pp.normalize_per_cell(adata_counts, counts_per_cell_after=1e4)
sc.pp.log1p(adata_counts)
sc.pp.scale(adata_counts, max_value=10)

adata_counts.uns['rank_genes_groups'] = adata_bin.uns['rank_genes_groups']
sc.pl.rank_genes_groups_dotplot(adata_counts, n_genes=20, dendrogram=False, save='_tfidf_scanpy.pdf', use_raw = False)

# %%
def Barplot(which_var, adata, var='clusters', height=3, color = False):
    plotdata = pd.crosstab(adata.obs[var], adata.obs[which_var], normalize='index') * 100
    if 'category' in plotdata.index.dtype.name:
        plotdata.index.reorder_categories(adata.obs[var].cat.categories[::-1])

    if not color:
        ax1 = plotdata.plot.barh(stacked = True, edgecolor = 'none', zorder = 3, figsize = (6,height), fontsize = 14, grid = False)
    else:
        ax1 = plotdata.plot.barh(stacked = True, edgecolor = 'none', zorder = 3, figsize = (6,height), fontsize = 14, grid = False, color = color)
    ax1.set_title(which_var+' %')
    ax1.set_ylabel(var)
    horiz_offset = 1
    vert_offset = 1.
    ax1 = ax1.legend(bbox_to_anchor = (horiz_offset, vert_offset))
    ax1.figure.savefig(str(sc.settings.figdir)+'/barplot_'+var+'_proportions_'+which_var+'.pdf', bbox_inches='tight',
                       dpi=300, orientation='landscape', format= 'pdf', optimize=True)

# %%
marker_genes = {
    'mesothelial':{'UPK3B'},
                'gonad_somatic_cells':{'NR5A1'},
                'supporting_lineage':{'WNT6', 'WIPF3'},
                'sLGR5':{'LGR5', 'SRY',  'GLUD2'},
                'sPAX8':{'PAX8', 'SST', 'PLAU', 'NTRK2', 'NRGN', 'PCP4'},
                'Sertoli':{'SOX9', 'INHBB', 'AMH', 'CLDN11', 'CITED1', 'SERPINA5'},
                'leydigFetal':{'INSL3',  'PTCH1',  'PTCH2',  'STAR'},
                'cycling':{'CDK1', 'MKI67'}  
}

# %%
marker_matches = sc.tl.marker_gene_overlap(adata_bin, marker_genes, method = 'overlap_coef')
marker_matches = marker_matches.set_axis('cl_'+marker_matches.columns, axis=1, inplace=False)

# %%
from pandas import DataFrame
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(5,4))  
sns.heatmap(marker_matches.T, annot=False, xticklabels=True, yticklabels=True, linewidths=0.5, ax= ax)

# %%
sc.pl.dotplot(adata_counts, marker_genes, groupby='leiden', standard_scale='var')

# %%
adata.obs['clusters'] = adata.obs['leiden'].tolist()
adata.obs.at[adata.obs['clusters'] == '0', 'clusters'] = 'Sertoli'
adata.obs.at[adata.obs['clusters'] == '1', 'clusters'] = 'FetalLeydig'
adata.obs.at[adata.obs['clusters'] == '2', 'clusters'] = 'Sertoli'
adata.obs.at[adata.obs['clusters'] == '3', 'clusters'] = 'Sertoli_cycling'
adata.obs.at[adata.obs['clusters'] == '4', 'clusters'] = 'sLGR5_sPAX8'
set(adata.obs['clusters'])
sc.pl.umap(adata, color=['clusters'])
adata.obs['clusters'].cat.reorder_categories(['sLGR5_sPAX8',
                                              'Sertoli', 'Sertoli_cycling', 'FetalLeydig'], inplace=True)

sc.pl.umap(adata, color=['clusters'])
# Out:
# ... storing 'clusters' as categorical

# %%
pd.DataFrame(adata.obs).to_csv('/nfs/team292/lg18/with_valentina/dual_snRNAsnATAC_male_Hrv15_supporting.csv')

# %%
sc.pl.dotplot(adata, marker_genes, groupby='clusters', standard_scale='var')

# %%
adata_counts = anndata.AnnData(X=adata.raw.X, var=adata.raw.var, obs=adata.obs, asview=False)

# Binarize counts matrix (1 if expressed, 0 otherwise)
import episcanpy as epi
adata_bin = epi.pp.binarize(adata_counts, copy=True)
adata_bin.X.shape
# Compute TF-IDF
from sklearn.feature_extraction.text import TfidfTransformer
transformer = TfidfTransformer()
tfidf = transformer.fit_transform(adata_bin.X.T)
adata_bin.X = tfidf.T
adata_bin.X.shape

#Compute Mann-Withney test with scanpy
sc.tl.rank_genes_groups(adata_bin, groupby='clusters', use_raw=False) #, method='logreg'

#Plot TF-IDF values
sc.pl.rank_genes_groups_dotplot(adata_bin, n_genes=30, dendrogram=False, save='_rawtfidf_scanpy.pdf')

# Plot with gene expression normalized values
sc.pp.normalize_per_cell(adata_counts, counts_per_cell_after=1e4)
sc.pp.log1p(adata_counts)
sc.pp.scale(adata_counts, max_value=10)

adata_counts.uns['rank_genes_groups'] = adata_bin.uns['rank_genes_groups']
sc.pl.rank_genes_groups_dotplot(adata_counts, n_genes=30, dendrogram=False, save='_tfidf_scanpy.pdf', use_raw = False)
# Out:
# WARNING: Default of the method has been changed to 't-test' from 't-test_overestim_var'
# ranking genes
#     finished: added to `.uns['rank_genes_groups']`
#     'names', sorted np.recarray to be indexed by group ids
#     'scores', sorted np.recarray to be indexed by group ids
#     'logfoldchanges', sorted np.recarray to be indexed by group ids
#     'pvals', sorted np.recarray to be indexed by group ids
#     'pvals_adj', sorted np.recarray to be indexed by group ids (0:00:00)
# WARNING: saving figure to file figures-sn/clustering_males/supporting/dotplot__rawtfidf_scanpy.pdf
# normalizing by total count per cell
#  FutureWarning:/opt/conda/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#     finished (0:00:00): normalized adata.X and added    'n_counts', counts per cell before normalization (adata.obs)
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# WARNING: saving figure to file figures-sn/clustering_males/supporting/dotplot__tfidf_scanpy.pdf
